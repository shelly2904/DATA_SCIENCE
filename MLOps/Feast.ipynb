# %% [markdown]
# Feast is a feature store library in Python.
# https://docs.feast.dev/quickstart

# %%
# pip install feast
# Out:
# ...
#      |████████████████████████████████| 194kB 4.2MB/s
# ...
#      |████████████████████████████████| 51kB 4.7MB/s
# ...
#      |████████████████████████████████| 276kB 6.9MB/s
# ...
#      |████████████████████████████████| 10.1MB 7.4MB/s
# ...
#      |████████████████████████████████| 102kB 10.2MB/s
# ...
#      |████████████████████████████████| 2.3MB 40.8MB/s
# ...
#   Created wheel for PyYAML: filename=PyYAML-5.3.1-cp37-cp37m-linux_x86_64.whl size=44636 sha256=4d79262cbd8e9fe3db322014c7e9a5990d6389700441aa1def31b0566640658b
#   Stored in directory: /root/.cache/pip/wheels/a7/c1/ea/cf5bd31012e735dc1dfea3131a2d5eae7978b251083d6247bd
# ...
#   Created wheel for pandavro: filename=pandavro-1.5.2-cp37-none-any.whl size=2954 sha256=0ed252be350e55cefb692ebf75380d562020dc305eb1d38e4939ceb15f252cc6
#   Stored in directory: /root/.cache/pip/wheels/9c/71/4f/f60022ad5c477241cb81edb1e29c50c55e98850224e0676ec6
# Successfully built PyYAML pandavro
# ...
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
# ...
