# %%
#From book: Computer Vision with Python by O'reilly

# %%
from PIL import Image
#Replace with any image
pil_im = Image.open('../data/Yoda.jpeg')
#.convert('L') Converts the color to Black and white

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-c8ec22b3e787> in <module>
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
pil_im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x900 at 0x10C1D0410>
