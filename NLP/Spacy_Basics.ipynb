# %%
# !pip install spacy
# !python -m spacy download en
# !python -m spacy download fr
# Out:
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.7/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.7/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')
# ...
#      |████████████████████████████████| 14.7MB 4.1MB/s
# ...
#   Created wheel for fr-core-news-sm: filename=fr_core_news_sm-2.2.5-cp37-none-any.whl size=14727027 sha256=395e91d7ed03b44aedf28effe4479964552b6d46aff2fe95d7910e1fbc4eed80
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3uhn1f3y/wheels/46/1b/e6/29b020e3f9420a24c3f463343afe5136aaaf955dbc9e46dfc5
# Successfully built fr-core-news-sm
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('fr_core_news_sm')
# ✔ Linking successful
# /usr/local/lib/python3.7/dist-packages/fr_core_news_sm -->
# /usr/local/lib/python3.7/dist-packages/spacy/data/fr
# You can now load the model via spacy.load('fr')

# %%
import spacy

nlp = spacy.load('en') # loads english model
doc = nlp(u"Hello world this is nlp in spacy")
doc.text
# Out:
# 'Hello world this is nlp in spacy'
